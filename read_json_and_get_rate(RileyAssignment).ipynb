# %% [markdown]
# **Read JSON and get rate of currency**

# %%
import json
import pandas

# %% [markdown]
# Read saved Json file

# %%
import json
  
f = open('json/resultByDay.json')
  
data = json.load(f)
  

f.close()

# %%
def get_rate(data, currency_name):
    rate_by_date_dict = {}
    record ={}
    for date in list(data.keys()):
        try:
            record[date] = float(data[date][currency_name+'_sgd'])
        except:
            record[date] = float(data[date]['{}_sgd_100'.format(currency_name)])
    rate_by_date_dict['currency'] = currency_name
    rate_by_date_dict['record'] = record
    return rate_by_date_dict

# %%
usd_rate = get_rate(data, 'usd')

# %%
usd_rate
# Out:
# {'currency': 'usd',
#  'record': {'2023-05-26': 1.3528,
#   '2023-05-25': 1.3524,
#   '2023-05-24': 1.3466,
#   '2023-05-23': 1.3456,
#   '2023-05-22': 1.3444,
#   '2023-05-19': 1.3486,
#   '2023-05-18': 1.3422,
#   '2023-05-17': 1.341,
#   '2023-05-16': 1.3359,
#   '2023-05-15': 1.3388,
#   '2023-05-12': 1.3316,
#   '2023-05-11': 1.3257,
#   '2023-05-10': 1.3265,
#   '2023-05-09': 1.3247,
#   '2023-05-08': 1.3254,
#   '2023-05-05': 1.3249,
#   '2023-05-04': 1.3277,
#   '2023-05-03': 1.3335,
#   '2023-05-02': 1.3363,
#   '2023-04-28': 1.334,
#   '2023-04-27': 1.3355,
#   '2023-04-26': 1.3378,
#   '2023-04-25': 1.3341,
#   '2023-04-24': 1.3359,
#   '2023-04-21': 1.3332,
#   '2023-04-20': 1.3343,
#   '2023-04-19': 1.3335,
#   '2023-04-18': 1.3343,
#   '2023-04-17': 1.3321,
#   '2023-04-14': 1.3241,
#   '2023-04-13': 1.3268,
#   '2023-04-12': 1.332,
#   '2023-04-11': 1.3315,
#   '2023-04-10': 1.33,
#   '2023-04-06': 1.3298,
#   '2023-04-05': 1.326,
#   '2023-04-04': 1.3276,
#   '2023-04-03': 1.3345,
#   '2023-03-31': 1.327,
#   '2023-03-30': 1.3303,
#   '2023-03-29': 1.3289,
#   '2023-03-28': 1.3284,
#   '2023-03-27': 1.3328,
#   '2023-03-24': 1.328,
#   '2023-03-23': 1.325,
#   '2023-03-22': 1.3368,
#   '2023-03-21': 1.3388,
#   '2023-03-20': 1.3419,
#   '2023-03-17': 1.3421,
#   '2023-03-16': 1.3508,
#   '2023-03-15': 1.342,
#   '2023-03-14': 1.348,
#   '2023-03-13': 1.3442,
#   '2023-03-10': 1.3558,
#   '2023-03-09': 1.3538,
#   '2023-03-08': 1.3561,
#   '2023-03-07': 1.3447,
#   '2023-03-06': 1.344,
#   '2023-03-03': 1.3475,
#   '2023-03-02': 1.3448,
#   '2023-03-01': 1.3466,
#   '2023-02-28': 1.348,
#   '2023-02-27': 1.3507,
#   '2023-02-24': 1.343,
#   '2023-02-23': 1.3383,
#   '2023-02-22': 1.3393,
#   '2023-02-21': 1.3376,
#   '2023-02-20': 1.3365,
#   '2023-02-17': 1.3394,
#   '2023-02-16': 1.3341,
#   '2023-02-15': 1.3324,
#   '2023-02-14': 1.3276,
#   '2023-02-13': 1.3327,
#   '2023-02-10': 1.3283,
#   '2023-02-09': 1.3259,
#   '2023-02-08': 1.3245,
#   '2023-02-07': 1.327,
#   '2023-02-06': 1.3241,
#   '2023-02-03': 1.3113,
#   '2023-02-02': 1.3043,
#   '2023-02-01': 1.3143,
#   '2023-01-31': 1.3142,
#   '2023-01-30': 1.3138,
#   '2023-01-27': 1.3137,
#   '2023-01-26': 1.312,
#   '2023-01-25': 1.3179,
#   '2023-01-20': 1.3228,
#   '2023-01-19': 1.3221,
#   '2023-01-18': 1.3243,
#   '2023-01-17': 1.322,
#   '2023-01-16': 1.3164,
#   '2023-01-13': 1.323,
#   '2023-01-12': 1.3304,
#   '2023-01-11': 1.3315,
#   '2023-01-10': 1.3312,
#   '2023-01-09': 1.331,
#   '2023-01-06': 1.3435,
#   '2023-01-05': 1.3423,
#   '2023-01-04': 1.3417,
#   '2023-01-03': 1.3373}}
